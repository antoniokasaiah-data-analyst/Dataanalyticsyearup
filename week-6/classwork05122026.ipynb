# %% [markdown]
# # Kasaiah Antonio
# # 05/12/2026
# def function

# %%
def greeting():
    name = input("please enter your name: ")
    

result = greeting()
print(f"hello, {result}!")
# Out:
# please enter your name:  kas
# hello, None!

# %%
def greeting():
    name = input("please enter your name: ")
    return name

result = greeting()
print(f"hello, {result}!")
# Out:
# please enter your name:  kaz
# hello, kaz!

# %%
print(greeting())
# Out:
# please enter your name:  kas
# kas

# %%
def greeting(name,city,hobby):
    return name,city, hobby


input("please enter your name: ")
input("please enter your city: ")
input("please enter your hobby: ")
result = greeting(name,city,hobby)

print(type(result))
print(f"hello, {result[0]}! You are from {result[1]} and you enjoy {result[2]}.")
# Out:
# please enter your name:  kas
# please enter your city:  as
# please enter your hobby:  asa
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       4
#       5 input("please enter your name: ")
#       6 input("please enter your city: ")
#       7 input("please enter your hobby: ")
# ----> 8 result = greeting(name,city,hobby)
#       9
#      10 print(type(result))
#      11 print(f"hello, {result[0]}! You are from {result[1]} and you enjoy {result[2]}.")
#
# NameError: name 'name' is not defined

# %%
def greeting(name, city, hobby):
    return name, city, hobby

name = input("Please enter your name: ")
city = input("Please enter your city: ")
hobby = input("Please enter your hobby: ")

result = greeting(name, city, hobby)

print(type(result))

print(f"Hello, {result[0]}! You are from {result[1]} and you enjoy {result[2]}.")
# Out:
# Please enter your name:  as
# Please enter your city:  sa
# Please enter your hobby:  as
# <class 'tuple'>
# Hello, as! You are from sa and you enjoy as.

# %%
def age():
    print(int(29))
age()
# Out:
# 29

# %%
# parameters are variables stored and used in functions
def age(name):
    print(f"{name}{int(29)}")
age(name)
# Out:
# asint(29)

# %%
result = age(antonio)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 result = age(antonio)
#       2 print(result)
#
# NameError: name 'antonio' is not defined

# %%
def person(name=" ",height=" ",):
    return(f" My name is {name} and I'm {height} tall.")

results1= person(name="kas",height="6ft")
print(results1)
# Out:
#  My name is kas and I'm 6ft tall.

# %%
def person():
    x = 10
    print(x)
# if you dont recall the function it wont print

# %%
def person():
    x = 10
    print(x)
person()
# function recalled
# Out:
# 10

# %%
results = person()
# if you assign a variable to a the function it prints the result without you having to recall it
# Out:
# 10

# %%
# if a parameter/variable is in a functions you ahve to define it when recalling the function for the code to work or run
# it is a run requirement 
#

# %%
# indexing
text = "python"

print("first character: ",text[0])
print("first character: ",text[-1])
# Out:
# first character:  p
# first character:  n

# %%
# slicing
print
